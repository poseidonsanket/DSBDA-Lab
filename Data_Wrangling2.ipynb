# %% [markdown]
# <a href="https://colab.research.google.com/github/poseidonsanket/DSBDA-Lab/blob/main/Data_Wrangling2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b2f8a0cb-8634-4fe5-a83d-24e1651d33cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2f8a0cb-8634-4fe5-a83d-24e1651d33cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
obj1=pd.read_csv("/content/Academic_Performance.csv")

# %%
obj1
# Out:
#    Roll_No      Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0        1    Sanket          36        54.0           54.0            5.0
# 1        2    Aniket          45        54.0           54.0          322.0
# 2        3    Bidgar          65       665.0           33.0            2.0
# 3        4   Bhosale          87         NaN           43.0            2.0
# 4        5     Aryan          65         NaN           57.0           22.0
# 5        6    Darade          45        87.0          353.0            2.0
# 6        7  VishVesh          45         8.0           36.0           23.0
# 7        8       tom          34        67.0           87.0          223.0
# 8        9     jerry          36        87.0            NaN            NaN
# 9       10  katarina          76         9.0            NaN            NaN
#
#    Total_Marks  Percentage Result
# 0          113   37.666667   PASS
# 1          430  143.333333   PASS
# 2          700  233.333333   PASS
# ...

# %%
obj1.head()
# Out:
#    Roll_No     Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0        1   Sanket          36        54.0           54.0            5.0
# 1        2   Aniket          45        54.0           54.0          322.0
# 2        3   Bidgar          65       665.0           33.0            2.0
# 3        4  Bhosale          87         NaN           43.0            2.0
# 4        5    Aryan          65         NaN           57.0           22.0
#
#    Total_Marks  Percentage Result
# 0          113   37.666667   PASS
# 1          430  143.333333   PASS
# 2          700  233.333333   PASS
# 3           45   15.000000   FAIL
# 4           79   26.333333   FAIL

# %%
obj1.tail()
# Out:
#    Roll_No      Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 5        6    Darade          45        87.0          353.0            2.0
# 6        7  VishVesh          45         8.0           36.0           23.0
# 7        8       tom          34        67.0           87.0          223.0
# 8        9     jerry          36        87.0            NaN            NaN
# 9       10  katarina          76         9.0            NaN            NaN
#
#    Total_Marks  Percentage Result
# 5          442  147.333333   PASS
# 6           67   22.333333   FAIL
# 7          377  125.666667   PASS
# 8           87   29.000000   FAIL
# 9            9    3.000000   FAIL

# %%
obj1.describe(include="all")
# Out:
#          Roll_No    Name  Attendance  Math_Marks  English_Marks  \
# count   10.00000      10   10.000000    8.000000       8.000000
# unique       NaN      10         NaN         NaN            NaN
# top          NaN  Sanket         NaN         NaN            NaN
# freq         NaN       1         NaN         NaN            NaN
# mean     5.50000     NaN   53.400000  128.875000      89.625000
# std      3.02765     NaN   18.566397  218.749327     107.724433
# min      1.00000     NaN   34.000000    8.000000      33.000000
# 25%      3.25000     NaN   38.250000   42.750000      41.250000
# 50%      5.50000     NaN   45.000000   60.500000      54.000000
# 75%      7.75000     NaN   65.000000   87.000000      64.500000
# max     10.00000     NaN   87.000000  665.000000     353.000000
#
#         Science_Marks  Total_Marks  Percentage Result
# count        8.000000    10.000000   10.000000     10
# unique            NaN          NaN         NaN      2
# ...

# %%
obj1.shape
# Out:
# (10, 9)

# %%
obj1.shape
# Out:
# (10, 9)

# %%
obj1.columns
# Out:
# Index(['Roll_No', 'Name', 'Attendance', 'Math_Marks', 'English_Marks',
#        'Science_Marks', 'Total_Marks', 'Percentage', 'Result'],
#       dtype='object')

# %%
obj1[0:5]
# Out:
#    Roll_No     Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0        1   Sanket          36        54.0           54.0            5.0
# 1        2   Aniket          45        54.0           54.0          322.0
# 2        3   Bidgar          65       665.0           33.0            2.0
# 3        4  Bhosale          87         NaN           43.0            2.0
# 4        5    Aryan          65         NaN           57.0           22.0
#
#    Total_Marks  Percentage Result
# 0          113   37.666667   PASS
# 1          430  143.333333   PASS
# 2          700  233.333333   PASS
# 3           45   15.000000   FAIL
# 4           79   26.333333   FAIL

# %%
obj1.loc[0:2]
# Out:
#    Roll_No    Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0        1  Sanket          36        54.0           54.0            5.0
# 1        2  Aniket          45        54.0           54.0          322.0
# 2        3  Bidgar          65       665.0           33.0            2.0
#
#    Total_Marks  Percentage Result
# 0          113   37.666667   PASS
# 1          430  143.333333   PASS
# 2          700  233.333333   PASS

# %%
obj1.iloc[1:3]
# Out:
#    Roll_No    Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 1        2  Aniket          45        54.0           54.0          322.0
# 2        3  Bidgar          65       665.0           33.0            2.0
#
#    Total_Marks  Percentage Result
# 1          430  143.333333   PASS
# 2          700  233.333333   PASS

# %%
obj1.iloc[1:5,1:5]
# Out:
#       Name  Attendance  Math_Marks  English_Marks
# 1   Aniket          45        54.0           54.0
# 2   Bidgar          65       665.0           33.0
# 3  Bhosale          87         NaN           43.0
# 4    Aryan          65         NaN           57.0

# %%
obj1.isnull()
# Out:
#    Roll_No   Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0    False  False       False       False          False          False
# 1    False  False       False       False          False          False
# 2    False  False       False       False          False          False
# 3    False  False       False        True          False          False
# 4    False  False       False        True          False          False
# 5    False  False       False       False          False          False
# 6    False  False       False       False          False          False
# 7    False  False       False       False          False          False
# 8    False  False       False       False           True           True
# 9    False  False       False       False           True           True
#
#    Total_Marks  Percentage  Result
# 0        False       False   False
# 1        False       False   False
# 2        False       False   False
# ...

# %%
obj1.isna()
# Out:
#    Roll_No   Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0    False  False       False       False          False          False
# 1    False  False       False       False          False          False
# 2    False  False       False       False          False          False
# 3    False  False       False        True          False          False
# 4    False  False       False        True          False          False
# 5    False  False       False       False          False          False
# 6    False  False       False       False          False          False
# 7    False  False       False       False          False          False
# 8    False  False       False       False           True           True
# 9    False  False       False       False           True           True
#
#    Total_Marks  Percentage  Result
# 0        False       False   False
# 1        False       False   False
# 2        False       False   False
# ...

# %%
obj1.isnull().any()
# Out:
# Roll_No          False
# Name             False
# Attendance       False
# Math_Marks        True
# English_Marks     True
# Science_Marks     True
# Total_Marks      False
# Percentage       False
# Result           False
# dtype: bool

# %%
obj1.isnull().sum()
# Out:
# Roll_No          0
# Name             0
# Attendance       0
# Math_Marks       2
# English_Marks    2
# Science_Marks    2
# Total_Marks      0
# Percentage       0
# Result           0
# dtype: int64

# %%
cols_with_na = []
for col in obj1.columns:
    if obj1[col].isna().any():
        cols_with_na.append(col)

cols_with_na
# Out:
# ['Math_Marks', 'English_Marks', 'Science_Marks']

# %%
obj1.replace(np.nan,value=0)
# Out:
#    Roll_No      Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0        1    Sanket          36        54.0           54.0            5.0
# 1        2    Aniket          45        54.0           54.0          322.0
# 2        3    Bidgar          65       665.0           33.0            2.0
# 3        4   Bhosale          87         0.0           43.0            2.0
# 4        5     Aryan          65         0.0           57.0           22.0
# 5        6    Darade          45        87.0          353.0            2.0
# 6        7  VishVesh          45         8.0           36.0           23.0
# 7        8       tom          34        67.0           87.0          223.0
# 8        9     jerry          36        87.0            0.0            0.0
# 9       10  katarina          76         9.0            0.0            0.0
#
#    Total_Marks  Percentage Result
# 0          113   37.666667   PASS
# 1          430  143.333333   PASS
# 2          700  233.333333   PASS
# ...

# %%
obj1.fillna(1)
# Out:
#    Roll_No      Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0        1    Sanket          36        54.0           54.0            5.0
# 1        2    Aniket          45        54.0           54.0          322.0
# 2        3    Bidgar          65       665.0           33.0            2.0
# 3        4   Bhosale          87         1.0           43.0            2.0
# 4        5     Aryan          65         1.0           57.0           22.0
# 5        6    Darade          45        87.0          353.0            2.0
# 6        7  VishVesh          45         8.0           36.0           23.0
# 7        8       tom          34        67.0           87.0          223.0
# 8        9     jerry          36        87.0            1.0            1.0
# 9       10  katarina          76         9.0            1.0            1.0
#
#    Total_Marks  Percentage Result
# 0          113   37.666667   PASS
# 1          430  143.333333   PASS
# 2          700  233.333333   PASS
# ...

# %%
obj1['Math_Marks']=obj1['Math_Marks'].fillna(obj1['Math_Marks'].mean())

# %%
obj1.head(10)
# Out:
#    Roll_No      Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0        1    Sanket          36      54.000           54.0            5.0
# 1        2    Aniket          45      54.000           54.0          322.0
# 2        3    Bidgar          65     665.000           33.0            2.0
# 3        4   Bhosale          87     128.875           43.0            2.0
# 4        5     Aryan          65     128.875           57.0           22.0
# 5        6    Darade          45      87.000          353.0            2.0
# 6        7  VishVesh          45       8.000           36.0           23.0
# 7        8       tom          34      67.000           87.0          223.0
# 8        9     jerry          36      87.000            NaN            NaN
# 9       10  katarina          76       9.000            NaN            NaN
#
#    Total_Marks  Percentage Result
# 0          113   37.666667   PASS
# 1          430  143.333333   PASS
# 2          700  233.333333   PASS
# ...

# %%
obj1.dropna()
# Out:
#    Roll_No      Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0        1    Sanket          36      54.000           54.0            5.0
# 1        2    Aniket          45      54.000           54.0          322.0
# 2        3    Bidgar          65     665.000           33.0            2.0
# 3        4   Bhosale          87     128.875           43.0            2.0
# 4        5     Aryan          65     128.875           57.0           22.0
# 5        6    Darade          45      87.000          353.0            2.0
# 6        7  VishVesh          45       8.000           36.0           23.0
# 7        8       tom          34      67.000           87.0          223.0
#
#    Total_Marks  Percentage Result
# 0          113   37.666667   PASS
# 1          430  143.333333   PASS
# 2          700  233.333333   PASS
# 3           45   15.000000   FAIL
# 4           79   26.333333   FAIL
# 5          442  147.333333   PASS
# 6           67   22.333333   FAIL
# ...

# %%
obj1.dropna(how="all")
# Out:
#    Roll_No      Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0        1    Sanket          36      54.000           54.0            5.0
# 1        2    Aniket          45      54.000           54.0          322.0
# 2        3    Bidgar          65     665.000           33.0            2.0
# 3        4   Bhosale          87     128.875           43.0            2.0
# 4        5     Aryan          65     128.875           57.0           22.0
# 5        6    Darade          45      87.000          353.0            2.0
# 6        7  VishVesh          45       8.000           36.0           23.0
# 7        8       tom          34      67.000           87.0          223.0
# 8        9     jerry          36      87.000            NaN            NaN
# 9       10  katarina          76       9.000            NaN            NaN
#
#    Total_Marks  Percentage Result
# 0          113   37.666667   PASS
# 1          430  143.333333   PASS
# 2          700  233.333333   PASS
# ...

# %%
obj1.dropna(axis=1)
# Out:
#    Roll_No      Name  Attendance  Math_Marks  Total_Marks  Percentage Result
# 0        1    Sanket          36      54.000          113   37.666667   PASS
# 1        2    Aniket          45      54.000          430  143.333333   PASS
# 2        3    Bidgar          65     665.000          700  233.333333   PASS
# 3        4   Bhosale          87     128.875           45   15.000000   FAIL
# 4        5     Aryan          65     128.875           79   26.333333   FAIL
# 5        6    Darade          45      87.000          442  147.333333   PASS
# 6        7  VishVesh          45       8.000           67   22.333333   FAIL
# 7        8       tom          34      67.000          377  125.666667   PASS
# 8        9     jerry          36      87.000           87   29.000000   FAIL
# 9       10  katarina          76       9.000            9    3.000000   FAIL

# %%
obj1.dropna(axis=0,how='any',inplace=True)

# %%
obj1
# Out:
#    Roll_No      Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0        1    Sanket          36      54.000           54.0            5.0
# 1        2    Aniket          45      54.000           54.0          322.0
# 2        3    Bidgar          65     665.000           33.0            2.0
# 3        4   Bhosale          87     128.875           43.0            2.0
# 4        5     Aryan          65     128.875           57.0           22.0
# 5        6    Darade          45      87.000          353.0            2.0
# 6        7  VishVesh          45       8.000           36.0           23.0
# 7        8       tom          34      67.000           87.0          223.0
#
#    Total_Marks  Percentage Result
# 0          113   37.666667   PASS
# 1          430  143.333333   PASS
# 2          700  233.333333   PASS
# 3           45   15.000000   FAIL
# 4           79   26.333333   FAIL
# 5          442  147.333333   PASS
# 6           67   22.333333   FAIL
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(obj1)
# Out:
# <Axes: >

# %%
obj1.boxplot()
# Out:
# <Axes: >

# %%
sns.boxplot(x=obj1.Total_Marks)
# Out:
# <Axes: xlabel='Total_Marks'>

# %%
sns.boxplot(x=obj1.Percentage)
# Out:
# <Axes: xlabel='Percentage'>

# %%
sns.boxplot(x=obj1.Math_Marks)
# Out:
# <Axes: xlabel='Math_Marks'>

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (9, 6)
obj1_list = ['Roll_No','Math_Marks','Total_Marks','Percentage']
fig, axes = plt.subplots(2, 2)
fig.set_dpi(120)

count=0
for r in range(2):
  for c in range(2):
    _ = obj1[obj1_list[count]].plot(kind = 'box', ax=axes[r,c])
    count+=1

# %%
Lower_limit = 0
Upper_limit = 100
print(f'Lower_limit = {Lower_limit}, Upper_limit = {Upper_limit}')
# Out:
# Lower_limit = 0, Upper_limit = 100

# %%
obj1[(obj1['Percentage'] < Lower_limit) | (obj1['Percentage'] > Upper_limit)]
# Out:
#    Roll_No    Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 1        2  Aniket          45        54.0           54.0          322.0
# 2        3  Bidgar          65       665.0           33.0            2.0
# 5        6  Darade          45        87.0          353.0            2.0
# 7        8     tom          34        67.0           87.0          223.0
#
#    Total_Marks  Percentage Result
# 1          430  143.333333   PASS
# 2          700  233.333333   PASS
# 5          442  147.333333   PASS
# 7          377  125.666667   PASS

# %%
outliers=[]
for i in obj1.Percentage:
  if i<Lower_limit or i>Upper_limit:
    outliers.append(i)
print("outliers are",outliers)
# Out:
# outliers are [143.3333333, 233.3333333, 147.3333333, 125.6666667]

# %%
Upper_limit
# Out:
# 100

# %%
Lower_limit
# Out:
# 0

# %%
obj1[obj1.Percentage<Lower_limit].index
# Out:
# Int64Index([], dtype='int64')

# %%
obj2=obj1.drop(obj1[obj1.Percentage<Lower_limit].index)

# %%
obj2.shape
# Out:
# (8, 9)

# %%
obj3=obj1[obj1.Percentage<Lower_limit]
obj3
# Out:
# Empty DataFrame
# Columns: [Roll_No, Name, Attendance, Math_Marks, English_Marks, Science_Marks, Total_Marks, Percentage, Result]
# Index: []

# %%
sns.kdeplot(obj1.Percentage)
# Out:
# <Axes: xlabel='Percentage', ylabel='Density'>

# %%
sns.kdeplot(obj2.Percentage)
# Out:
# <Axes: xlabel='Percentage', ylabel='Density'>

# %%
obj1.Percentage
# Out:
# 0     37.666667
# 1    143.333333
# 2    233.333333
# 3     15.000000
# 4     26.333333
# 5    147.333333
# 6     22.333333
# 7    125.666667
# Name: Percentage, dtype: float64

# %%
log_percentage=np.log(obj1.Percentage)
log_percentage
# Out:
# 0    3.628776
# 1    4.965173
# 2    5.452468
# 3    2.708050
# 4    3.270836
# 5    4.992698
# 6    3.106080
# 7    4.833633
# Name: Percentage, dtype: float64

# %%
sns.kdeplot(log_percentage)
# Out:
# <Axes: xlabel='Percentage', ylabel='Density'>

# %%
import seaborn as sns

# %%
obj1.skew()
# Out:
# <ipython-input-69-28a64991558c>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   obj1.skew()
# Roll_No          0.000000
# Attendance       1.006237
# Math_Marks       2.626319
# English_Marks    2.698018
# Science_Marks    1.607634
# Total_Marks      0.622860
# Percentage       0.622860
# dtype: float64

# %%
sns.kdeplot(obj1.Attendance);

# %%
sns.kdeplot(obj1.Math_Marks);

# %%
sns.kdeplot(obj1.English_Marks);

# %%
sns.kdeplot(obj1.Science_Marks);

# %%
sns.kdeplot(obj1.Total_Marks);

# %%
sns.kdeplot(obj1.Percentage);
